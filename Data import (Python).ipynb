# %%
import pandas as pd
import statistics
import numpy as np

# %%
pd.read_excel(r"C:\Users\kevin\OneDrive\Documentos\Excel\Insumos.xlsx.xlsx") #"r" convierte cadena simple a cadena en bruto
# Out:
#        Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0             NaN        Pol        Def      P_Cob      P_Pag      E_Con
# 1             NaN          1          D         25         25         16
# 2             NaN         17          D         35          2         42
# 3             NaN         25          D         35          1         41
# 4             NaN         27          D         10          7         51
# ...           ...        ...        ...        ...        ...        ...
# 73254         NaN      73250          V          -         25         26
# 73255         NaN      73253          V          -          1         39
# 73256         NaN      73255          V          -         10         63
# 73257         NaN      73257          V          -          -         37
# 73258         NaN      73258          V          -          5         37
#
#       Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# ...

# %%
pd.read_csv(r"C:\Users\kevin\Dropbox\Pythonconda\house.csv")
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
house= pd.read_csv(r"C:\Users\kevin\Dropbox\Pythonconda\house.csv")

# %%
house
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
meanl= house["latitude"].mean() #renombrar dataframe para definir el promedio

# %%
meanl
# Out:
# 35.6318614341087

# %%
varl = house["latitude"].var() #esta es la varianza muestral

# %%
varl
# Out:
# 4.562292644202784

# %%
from statistics import pvariance

# %%
pvariance(house["latitude"]) #esta corresponde a la varianza poblacional, también conocida como teórica
# Out:
# 4.562071602892517

# %%
mediana= house["latitude"].median()

# %%
mediana
# Out:
# 34.26

# %%
moda= house["latitude"].mode()

# %%
moda
# Out:
# 0    34.06
# Name: latitude, dtype: float64

# %% [markdown]
# O simplemente

# %%
house.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Luego de ver un poco de estadística descriptiva, podemos continuar con las gráficas:

# %% [markdown]
# Columnas vs columnas

# %%
sns.pairplot(house)

# %%
sns.pairplot(house.sample(1000)) #a pares tomando 1000 datos por columna para optimizar tiempo

# %% [markdown]
# Los graficos representan el concepto de matriz de varianzas:

# %%
housecc = house.corr()

# %%
housecc
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.984177           -0.186699     0.140731
# latitude            -0.984177  1.000000            0.113555    -0.100535
# housing_median_age  -0.186699  0.113555            1.000000    -0.806298
# total_rooms          0.140731 -0.100535           -0.806298     1.000000
# total_bedrooms       0.165913 -0.115735           -0.755412     0.986973
# population           0.204567 -0.151290           -0.745965     0.976312
# households           0.160745 -0.113873           -0.749883     0.987362
# median_income        0.000943 -0.115833           -0.125555    -0.090886
# median_house_value  -0.003711 -0.151589            0.104792    -0.186884
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.165913    0.204567    0.160745       0.000943
# latitude                 -0.115735   -0.151290   -0.113873      -0.115833
# ...

# %%
data = [21, 19, 18, 46, 30]
print(statistics.mean(data))
# Out:
# 26.8

# %%
x=[1,2,3,4,5]
print(statistics.mean(x))
# Out:
# 3
