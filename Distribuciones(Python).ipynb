# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Iniciemos viendo las distribuciones de probabilidad más frecuentes (funciones de densidad de probabilidad):
#
# Distribución Uniforme continua: $$ f(x)= \frac{1}{b-a}\mathbb{1}_{(a,b)}(x) $$

# %%
import scipy.stats

# %%
from scipy.stats import uniform

# %%
n=10000 #simular
start=0
width=10
data_uniform=uniform.rvs(size=n, loc=start, scale=width) #tamaño de la muestra, inicio y fin

# %%
ax = sns.distplot(data_uniform,
                  bins=100, #grupos de datos
                  kde=True, #kernel de la función
                  color='green',
                  hist_kws={"linewidth": 22,'alpha':1})
ax.set(xlabel='Distribución uniforme continua ', ylabel="Frecuencia")
# Out:
# C:\Users\kevin\Dropbox\Python 3.9\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Distribución uniforme continua '), Text(0, 0.5, 'Frecuencia')]

# %% [markdown]
# Distribución Normal: $$f(x|\mu,\sigma^2)= \frac{1}{\sqrt{2\pi\sigma^2}}e^{-\frac{(x-\mu)^2}{2\sigma^2}}\mathbb{1}_{\mathbb{R}}(x)$$

# %%
from scipy.stats import norm

# %%
n=10000
start = 5
width = 1
data_normal=norm.rvs(size=n,loc=start,scale=width)

# %%
ax = sns.distplot(data_normal,
                  bins=100, #grupos de datos
                  kde=True, #kernel de la función
                  color='gray',
                  hist_kws={"linewidth": 22,'alpha':1})
ax.set(xlabel='Distribución normal ', ylabel="Frecuencia")
# Out:
# C:\Users\kevin\Dropbox\Python 3.9\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Distribución normal '), Text(0, 0.5, 'Frecuencia')]

# %% [markdown]
# Distribución Gamma: $$f(x|\alpha,\beta)= \frac{\beta^{\alpha} x^{\alpha-1}e^{-\beta x}}{\Gamma(\alpha)} \mathbb{1}_{\mathbb{R^+}}(x)$$ para  $$x,\alpha, \beta > 0$$

# %%
from scipy.stats import gamma

# %%
n=10000
start = 5
width = 1

data_gamma=gamma.rvs(a=5,size=n) #notar qué parámetros acepta la función

# %%
ax = sns.distplot(data_gamma,
                  bins=100, #grupos de datos
                  kde=True, #kernel de la función
                  color='blue',
                  hist_kws={"linewidth": 22,'alpha':1}) 
ax.set(xlabel='Distribución Gamma ', ylabel="Frecuencia")
# Out:
# C:\Users\kevin\Dropbox\Python 3.9\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Distribución Gamma '), Text(0, 0.5, 'Frecuencia')]

# %% [markdown]
# Distribución Exponencial: $$f(x)= \lambda e^{-\lambda x}\mathbb{1}_{\mathbb{R^+}}(x)$$

# %%
from scipy.stats import expon

# %%
n=10000
start = 5
width = 1

data_expon = expon.rvs(scale=width,loc=start,size=n)

# %%
ax = sns.distplot(data_expon,
                  kde=True,
                  bins=100,
                  color='red',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Distribución exponencial', ylabel='Frequency')
# Out:
# C:\Users\kevin\Dropbox\Python 3.9\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Distribución exponencial'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# Distribución Poisson: $$P(X=x)= e^{-\lambda} \frac{\lambda^{x}}{x!}\mathbb{1}_{{0,1,2 \dots}}(x)$$

# %%
from scipy.stats import poisson

# %%
n=10000
start = 1
width = 1

data_poisson = poisson.rvs(mu=start,size=n)

# %%
ax = sns.distplot(data_poisson,
                  kde=False, #notar que aquí interesa la frecuencia, en las anteriores (continua) se mostraban las probabilidades
                  bins=50,
                  color='black',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Distribución Poisson', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Distribución Poisson'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# Además de la Poisson, hay otras dos distribuciones discretas importantes:

# %% [markdown]
# Distribución Binomial:  $$P(X=x)=  {n \choose x} p^x(1-p)^{n-x}\mathbb{1}_{{0,1,2 \dots}, n}(x) $$

# %%
from scipy.stats import binom

# %%
data_binomial = binom.rvs(n=40,p=0.1,size=10000)

# %%
ax = sns.distplot(data_binomial,
                  kde=False,
                  bins=50,
                  color='yellow',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Distribución binomial', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Distribución binomial'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# Distribución Bernoulli: $$P(X=x)=  {1 \choose x} p^x(1-p)^{1-x}\mathbb{1}_{{0,1,2 \dots}, n}(x)=p^x(1-p)^{1-x}\mathbb{1}_{{0,1,2 \dots}, n}(x) $$

# %%
from scipy.stats import bernoulli

# %%
data_bernoulli = bernoulli.rvs(p=0.7,size=10000) #como casi siempre, se utilizan los parámetros de la función que corresponde

# %%
ax = sns.distplot(data_bernoulli,
                  kde=False,
                  bins=50,
                  color='brown',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Distribución Bernoulli', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Distribución Bernoulli'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# Notar que la probabilidad es casi $0$, por lo que la distribución está sesgada a la izquierda.
#
# Los procedimientos para graficar son muy parecidos: identificar los parámetros de la función, $size$ (es el número de intentos) y el código propio por distribución.
